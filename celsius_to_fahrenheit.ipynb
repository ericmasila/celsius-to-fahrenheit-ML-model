# %% [markdown]
# in this simple machine learning model, i will convert from celsius to fahrenheit.
# The exact formula is:
#     f = c * 1.8 +32

# %%
import tensorflow as tf

# %%
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# #Setting up training data

# %%
celsius_q = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit_a = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

for i,c in enumerate(celsius_q):
  print("{} degrees celsius = {} degrees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees celsius = -40.0 degrees Fahrenheit
# -10.0 degrees celsius = 14.0 degrees Fahrenheit
# 0.0 degrees celsius = 32.0 degrees Fahrenheit
# 8.0 degrees celsius = 46.0 degrees Fahrenheit
# 15.0 degrees celsius = 59.0 degrees Fahrenheit
# 22.0 degrees celsius = 72.0 degrees Fahrenheit
# 38.0 degrees celsius = 100.0 degrees Fahrenheit

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print('Finished training the model')
# Out:
# Finished training the model

# %% [markdown]
# #Display training statistics

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel('Loss Magnitude')
plt.plot(history.history['loss'])

# %% [markdown]
# #using our model to predict values

# %%
print(model.predict([100.0]))
# Out:
# [[211.33818]]

# %% [markdown]
# #looking at the layer weights

# %%
print('These are the layer variables: {}'.format(l0.get_weights()))
# Out:
# These are the layer variables: [array([[1.8201541]], dtype=float32), array([29.32277], dtype=float32)]
